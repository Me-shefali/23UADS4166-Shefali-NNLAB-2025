# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess data
x_train = x_train.reshape(-1, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(-1, 784).astype(np.float32) / 255.0
y_train = tf.one_hot(y_train, depth=10)
y_test = tf.one_hot(y_test, depth=10)

# Hyperparameter combinations
hidden_layer_configs = [(160, 100), (100, 100), (100, 160), (60, 60), (100, 60)]
learning_rates = [0.01, 0.1, 1.0]
num_epochs = 20
batch_size = 10
n_input = 784
n_output = 10

# Iterate over different configurations
for (n_hidden1, n_hidden2) in hidden_layer_configs:
    for learning_rate in learning_rates:
        print(f"\nHidden Layers: ({n_hidden1}, {n_hidden2}), Learning Rate: {learning_rate}")

        # Initialize weights and biases
        initializer = tf.initializers.GlorotUniform()
        W1 = tf.Variable(initializer([n_input, n_hidden1]))
        b1 = tf.Variable(tf.zeros([n_hidden1]))
        W2 = tf.Variable(initializer([n_hidden1, n_hidden2]))
        b2 = tf.Variable(tf.zeros([n_hidden2]))
        W3 = tf.Variable(initializer([n_hidden2, n_output]))
        b3 = tf.Variable(tf.zeros([n_output]))

        # Define forward pass
        def forward_pass(x):
            z1 = tf.add(tf.matmul(x, W1), b1)
            a1 = tf.nn.relu(z1)  # ReLU activation
            z2 = tf.add(tf.matmul(a1, W2), b2)
            a2 = tf.nn.relu(z2)  # ReLU activation
            logits = tf.add(tf.matmul(a2, W3), b3)
            return logits

        # Loss function
        def compute_loss(logits, labels):
            return tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits))

        # Accuracy metric
        def compute_accuracy(logits, labels):
            correct_preds = tf.equal(tf.argmax(logits, axis=1), tf.argmax(labels, axis=1))
            return tf.reduce_mean(tf.cast(correct_preds, tf.float32))

        # Optimizer
        optimizer = tf.optimizers.SGD(learning_rate)

        # Training loop
        train_losses, test_accuracies = [], []
        start_time = time.time()
        for epoch in range(num_epochs):
            for i in range(0, x_train.shape[0], batch_size):
                x_batch = x_train[i:i + batch_size]
                y_batch = y_train[i:i + batch_size]

                with tf.GradientTape() as tape:
                    logits = forward_pass(x_batch)
                    loss = compute_loss(logits, y_batch)

                gradients = tape.gradient(loss, [W1, b1, W2, b2, W3, b3])
                optimizer.apply_gradients(zip(gradients, [W1, b1, W2, b2, W3, b3]))

            # Evaluate after each epoch
            test_logits = forward_pass(x_test)
            test_accuracy = compute_accuracy(test_logits, y_test)
            train_losses.append(loss.numpy())
            test_accuracies.append(test_accuracy.numpy())
            print(f"Epoch: {epoch + 1}, Loss: {loss.numpy():.4f}, Test Accuracy: {test_accuracy.numpy():.4f}")

        # Calculate execution time
        execution_time = time.time() - start_time
        print(f"Execution Time: {execution_time:.2f} seconds")

        # Plot loss and accuracy curves
        plt.figure(figsize=(12, 5))
        plt.plot(range(1, num_epochs + 1), train_losses, marker='o', label='Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.title(f'Loss Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()

        plt.figure(figsize=(12, 5))
        plt.plot(range(1, num_epochs + 1), test_accuracies, marker='o', color='g', label='Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.title(f'Accuracy Curve (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.legend()
        plt.show()

        # Confusion matrix
        y_pred = tf.argmax(forward_pass(x_test), axis=1).numpy()
        y_true = tf.argmax(y_test, axis=1).numpy()
        conf_matrix = confusion_matrix(y_true, y_pred)

        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f'Confusion Matrix (LR={learning_rate}, HL={n_hidden1},{n_hidden2})')
        plt.show()
# Out:
# Hidden Layers: (160, 100), Learning Rate: 0.01
# Epoch: 1, Loss: 0.0484, Test Accuracy: 0.9338
# Epoch: 2, Loss: 0.0284, Test Accuracy: 0.9503
# Epoch: 3, Loss: 0.0195, Test Accuracy: 0.9582
# Epoch: 4, Loss: 0.0135, Test Accuracy: 0.9631
# Epoch: 5, Loss: 0.0107, Test Accuracy: 0.9679
# Epoch: 6, Loss: 0.0088, Test Accuracy: 0.9697
# Epoch: 7, Loss: 0.0066, Test Accuracy: 0.9710
# Epoch: 8, Loss: 0.0055, Test Accuracy: 0.9724
# Epoch: 9, Loss: 0.0046, Test Accuracy: 0.9730
# Epoch: 10, Loss: 0.0041, Test Accuracy: 0.9731
# Epoch: 11, Loss: 0.0037, Test Accuracy: 0.9741
# Epoch: 12, Loss: 0.0031, Test Accuracy: 0.9750
# Epoch: 13, Loss: 0.0025, Test Accuracy: 0.9753
# Epoch: 14, Loss: 0.0022, Test Accuracy: 0.9764
# Epoch: 15, Loss: 0.0019, Test Accuracy: 0.9768
# Epoch: 16, Loss: 0.0018, Test Accuracy: 0.9767
# Epoch: 17, Loss: 0.0015, Test Accuracy: 0.9770
# Epoch: 18, Loss: 0.0014, Test Accuracy: 0.9769
# Epoch: 19, Loss: 0.0012, Test Accuracy: 0.9767
# Epoch: 20, Loss: 0.0011, Test Accuracy: 0.9766
# Execution Time: 1942.38 seconds
# Hidden Layers: (160, 100), Learning Rate: 0.1
# Epoch: 1, Loss: 0.0087, Test Accuracy: 0.9542
# Epoch: 2, Loss: 0.0011, Test Accuracy: 0.9643
# Epoch: 3, Loss: 0.0009, Test Accuracy: 0.9679
# Epoch: 4, Loss: 0.0003, Test Accuracy: 0.9688
# Epoch: 5, Loss: 0.0005, Test Accuracy: 0.9732
# Epoch: 6, Loss: 0.0001, Test Accuracy: 0.9752
# Epoch: 7, Loss: 0.0000, Test Accuracy: 0.9724
# Epoch: 8, Loss: 0.0044, Test Accuracy: 0.9751
# Epoch: 9, Loss: 0.0000, Test Accuracy: 0.9753
# Epoch: 10, Loss: 0.0000, Test Accuracy: 0.9773
# Epoch: 11, Loss: 0.0001, Test Accuracy: 0.9787
# Epoch: 12, Loss: 0.0000, Test Accuracy: 0.9801
# Epoch: 13, Loss: 0.0001, Test Accuracy: 0.9765
# Epoch: 14, Loss: 0.0001, Test Accuracy: 0.9789
# Epoch: 15, Loss: 0.0001, Test Accuracy: 0.9786
# Epoch: 16, Loss: 0.0000, Test Accuracy: 0.9755
# Epoch: 17, Loss: 0.0003, Test Accuracy: 0.9752
# Epoch: 18, Loss: 0.0001, Test Accuracy: 0.9772
# Epoch: 19, Loss: 0.0000, Test Accuracy: 0.9800
# Epoch: 20, Loss: 0.0000, Test Accuracy: 0.9770
# Execution Time: 2656.22 seconds
# Hidden Layers: (160, 100), Learning Rate: 1.0
# Epoch: 1, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 2, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 3, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 4, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 5, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 6, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 7, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 8, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 9, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 10, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 11, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 12, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 13, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 14, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 15, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 16, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 17, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 18, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 19, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1195.03 seconds
# Hidden Layers: (100, 100), Learning Rate: 0.01
# Epoch: 1, Loss: 0.0552, Test Accuracy: 0.9298
# Epoch: 2, Loss: 0.0434, Test Accuracy: 0.9468
# Epoch: 3, Loss: 0.0307, Test Accuracy: 0.9554
# Epoch: 4, Loss: 0.0213, Test Accuracy: 0.9614
# Epoch: 5, Loss: 0.0146, Test Accuracy: 0.9657
# Epoch: 6, Loss: 0.0109, Test Accuracy: 0.9688
# Epoch: 7, Loss: 0.0087, Test Accuracy: 0.9717
# Epoch: 8, Loss: 0.0074, Test Accuracy: 0.9730
# Epoch: 9, Loss: 0.0064, Test Accuracy: 0.9737
# Epoch: 10, Loss: 0.0056, Test Accuracy: 0.9733
# Epoch: 11, Loss: 0.0047, Test Accuracy: 0.9742
# Epoch: 12, Loss: 0.0041, Test Accuracy: 0.9744
# Epoch: 13, Loss: 0.0034, Test Accuracy: 0.9748
# Epoch: 14, Loss: 0.0029, Test Accuracy: 0.9741
# Epoch: 15, Loss: 0.0025, Test Accuracy: 0.9744
# Epoch: 16, Loss: 0.0022, Test Accuracy: 0.9737
# Epoch: 17, Loss: 0.0019, Test Accuracy: 0.9740
# Epoch: 18, Loss: 0.0016, Test Accuracy: 0.9743
# Epoch: 19, Loss: 0.0014, Test Accuracy: 0.9747
# Epoch: 20, Loss: 0.0013, Test Accuracy: 0.9740
# Execution Time: 1785.26 seconds
# Hidden Layers: (100, 100), Learning Rate: 0.1
# Epoch: 1, Loss: 0.0021, Test Accuracy: 0.9519
# Epoch: 2, Loss: 0.0011, Test Accuracy: 0.9652
# Epoch: 3, Loss: 0.0007, Test Accuracy: 0.9668
# Epoch: 4, Loss: 0.0038, Test Accuracy: 0.9691
# Epoch: 5, Loss: 0.0005, Test Accuracy: 0.9718
# Epoch: 6, Loss: 0.0007, Test Accuracy: 0.9769
# Epoch: 7, Loss: 0.0001, Test Accuracy: 0.9737
# Epoch: 8, Loss: 0.0001, Test Accuracy: 0.9732
# Epoch: 9, Loss: 0.0004, Test Accuracy: 0.9715
# Epoch: 10, Loss: 0.0003, Test Accuracy: 0.9726
# Epoch: 11, Loss: 0.0001, Test Accuracy: 0.9731
# Epoch: 12, Loss: 0.0001, Test Accuracy: 0.9719
# Epoch: 13, Loss: 0.0000, Test Accuracy: 0.9770
# Epoch: 14, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch: 15, Loss: 0.0000, Test Accuracy: 0.9724
# Epoch: 16, Loss: 0.0000, Test Accuracy: 0.9748
# Epoch: 17, Loss: 0.0000, Test Accuracy: 0.9755
# Epoch: 18, Loss: 0.0003, Test Accuracy: 0.9686
# Epoch: 19, Loss: 0.0000, Test Accuracy: 0.9769
# Epoch: 20, Loss: 0.0000, Test Accuracy: 0.9780
# Execution Time: 1192.42 seconds
# Hidden Layers: (100, 100), Learning Rate: 1.0
# Epoch: 1, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 2, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 3, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 4, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 5, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 6, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 7, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 8, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 9, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 10, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 11, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 12, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 13, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 14, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 15, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 16, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 17, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 18, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 19, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1193.86 seconds
# Hidden Layers: (100, 160), Learning Rate: 0.01
# Epoch: 1, Loss: 0.0429, Test Accuracy: 0.9303
# Epoch: 2, Loss: 0.0232, Test Accuracy: 0.9496
# Epoch: 3, Loss: 0.0152, Test Accuracy: 0.9577
# Epoch: 4, Loss: 0.0106, Test Accuracy: 0.9621
# Epoch: 5, Loss: 0.0074, Test Accuracy: 0.9658
# Epoch: 6, Loss: 0.0053, Test Accuracy: 0.9676
# Epoch: 7, Loss: 0.0042, Test Accuracy: 0.9691
# Epoch: 8, Loss: 0.0033, Test Accuracy: 0.9698
# Epoch: 9, Loss: 0.0027, Test Accuracy: 0.9708
# Epoch: 10, Loss: 0.0022, Test Accuracy: 0.9720
# Epoch: 11, Loss: 0.0019, Test Accuracy: 0.9730
# Epoch: 12, Loss: 0.0015, Test Accuracy: 0.9728
# Epoch: 13, Loss: 0.0013, Test Accuracy: 0.9729
# Epoch: 14, Loss: 0.0011, Test Accuracy: 0.9729
# Epoch: 15, Loss: 0.0009, Test Accuracy: 0.9729
# Epoch: 16, Loss: 0.0008, Test Accuracy: 0.9726
# Epoch: 17, Loss: 0.0008, Test Accuracy: 0.9722
# Epoch: 18, Loss: 0.0007, Test Accuracy: 0.9726
# Epoch: 19, Loss: 0.0006, Test Accuracy: 0.9733
# Epoch: 20, Loss: 0.0006, Test Accuracy: 0.9738
# Execution Time: 1193.91 seconds
# Hidden Layers: (100, 160), Learning Rate: 0.1
# Epoch: 1, Loss: 0.0035, Test Accuracy: 0.9566
# Epoch: 2, Loss: 0.0021, Test Accuracy: 0.9632
# Epoch: 3, Loss: 0.0007, Test Accuracy: 0.9675
# Epoch: 4, Loss: 0.0003, Test Accuracy: 0.9695
# Epoch: 5, Loss: 0.0002, Test Accuracy: 0.9695
# Epoch: 6, Loss: 0.0005, Test Accuracy: 0.9684
# Epoch: 7, Loss: 0.0001, Test Accuracy: 0.9710
# Epoch: 8, Loss: 0.0000, Test Accuracy: 0.9737
# Epoch: 9, Loss: 0.0000, Test Accuracy: 0.9707
# Epoch: 10, Loss: 0.0000, Test Accuracy: 0.9735
# Epoch: 11, Loss: 0.0001, Test Accuracy: 0.9689
# Epoch: 12, Loss: 0.0002, Test Accuracy: 0.9738
# Epoch: 13, Loss: 0.0000, Test Accuracy: 0.9745
# Epoch: 14, Loss: 0.0000, Test Accuracy: 0.9696
# Epoch: 15, Loss: 0.0000, Test Accuracy: 0.9764
# Epoch: 16, Loss: 0.0000, Test Accuracy: 0.9779
# Epoch: 17, Loss: 0.0000, Test Accuracy: 0.9760
# Epoch: 18, Loss: 0.0000, Test Accuracy: 0.9759
# Epoch: 19, Loss: 0.0000, Test Accuracy: 0.9737
# Epoch: 20, Loss: 0.0000, Test Accuracy: 0.9728
# Execution Time: 1346.39 seconds
# Hidden Layers: (100, 160), Learning Rate: 1.0
# Epoch: 1, Loss: 2.3436, Test Accuracy: 0.0952
# Epoch: 2, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 3, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 4, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 5, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 6, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 7, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 8, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 9, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 10, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 11, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 12, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 13, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 14, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 15, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 16, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 17, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 18, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 19, Loss: 2.3437, Test Accuracy: 0.0959
# Epoch: 20, Loss: 2.3437, Test Accuracy: 0.0959
# Execution Time: 1294.94 seconds
# Hidden Layers: (60, 60), Learning Rate: 0.01
# Epoch: 1, Loss: 0.0477, Test Accuracy: 0.9279
# Epoch: 2, Loss: 0.0266, Test Accuracy: 0.9435
# Epoch: 3, Loss: 0.0188, Test Accuracy: 0.9501
# Epoch: 4, Loss: 0.0143, Test Accuracy: 0.9568
# Epoch: 5, Loss: 0.0116, Test Accuracy: 0.9596
# Epoch: 6, Loss: 0.0094, Test Accuracy: 0.9606
# Epoch: 7, Loss: 0.0080, Test Accuracy: 0.9612
# Epoch: 8, Loss: 0.0066, Test Accuracy: 0.9643
# Epoch: 9, Loss: 0.0054, Test Accuracy: 0.9658
# Epoch: 10, Loss: 0.0049, Test Accuracy: 0.9660
# Epoch: 11, Loss: 0.0043, Test Accuracy: 0.9680
# Epoch: 12, Loss: 0.0039, Test Accuracy: 0.9679
# Epoch: 13, Loss: 0.0035, Test Accuracy: 0.9682
# Epoch: 14, Loss: 0.0031, Test Accuracy: 0.9691
# Epoch: 15, Loss: 0.0027, Test Accuracy: 0.9691
# Epoch: 16, Loss: 0.0023, Test Accuracy: 0.9696
# Epoch: 17, Loss: 0.0019, Test Accuracy: 0.9704
# Epoch: 18, Loss: 0.0017, Test Accuracy: 0.9709
# Epoch: 19, Loss: 0.0013, Test Accuracy: 0.9711
# Epoch: 20, Loss: 0.0012, Test Accuracy: 0.9717
# Execution Time: 1036.58 seconds
# Hidden Layers: (60, 60), Learning Rate: 0.1
# Epoch: 1, Loss: 0.0021, Test Accuracy: 0.9497
# Epoch: 2, Loss: 0.0034, Test Accuracy: 0.9564
# Epoch: 3, Loss: 0.0007, Test Accuracy: 0.9625
# Epoch: 4, Loss: 0.0003, Test Accuracy: 0.9677
# Epoch: 5, Loss: 0.0001, Test Accuracy: 0.9688
# Epoch: 6, Loss: 0.0000, Test Accuracy: 0.9563
# Epoch: 7, Loss: 0.0000, Test Accuracy: 0.9676
# Epoch: 8, Loss: 0.0006, Test Accuracy: 0.9622
# Epoch: 9, Loss: 0.0000, Test Accuracy: 0.9678
# Epoch: 10, Loss: 0.0000, Test Accuracy: 0.9674
# Epoch: 11, Loss: 0.0000, Test Accuracy: 0.9675
# Epoch: 12, Loss: 0.0000, Test Accuracy: 0.9677
# Epoch: 13, Loss: 0.0000, Test Accuracy: 0.9725
# Epoch: 14, Loss: 0.0000, Test Accuracy: 0.9724
# Epoch: 15, Loss: 0.0000, Test Accuracy: 0.9707
# Epoch: 16, Loss: 0.0000, Test Accuracy: 0.9700
# Epoch: 17, Loss: 0.0000, Test Accuracy: 0.9715
# Epoch: 18, Loss: 0.0000, Test Accuracy: 0.9722
# Epoch: 19, Loss: 0.0000, Test Accuracy: 0.9704
# Epoch: 20, Loss: 0.0000, Test Accuracy: 0.9691
# Execution Time: 2018.39 seconds
# Hidden Layers: (60, 60), Learning Rate: 1.0
# Epoch: 1, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 2, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 3, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 4, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 5, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 6, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 7, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 8, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 9, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 10, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 11, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 12, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 13, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 14, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 15, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 16, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 17, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 18, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 19, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1610.63 seconds
# Hidden Layers: (100, 60), Learning Rate: 0.01
# Epoch: 1, Loss: 0.0802, Test Accuracy: 0.9296
# Epoch: 2, Loss: 0.0477, Test Accuracy: 0.9483
# Epoch: 3, Loss: 0.0271, Test Accuracy: 0.9578
# Epoch: 4, Loss: 0.0156, Test Accuracy: 0.9647
# Epoch: 5, Loss: 0.0097, Test Accuracy: 0.9675
# Epoch: 6, Loss: 0.0068, Test Accuracy: 0.9702
# Epoch: 7, Loss: 0.0048, Test Accuracy: 0.9726
# Epoch: 8, Loss: 0.0041, Test Accuracy: 0.9735
# Epoch: 9, Loss: 0.0035, Test Accuracy: 0.9738
# Epoch: 10, Loss: 0.0031, Test Accuracy: 0.9743
# Epoch: 11, Loss: 0.0027, Test Accuracy: 0.9742
# Epoch: 12, Loss: 0.0023, Test Accuracy: 0.9741
# Epoch: 13, Loss: 0.0022, Test Accuracy: 0.9739
# Epoch: 14, Loss: 0.0020, Test Accuracy: 0.9740
# Epoch: 15, Loss: 0.0019, Test Accuracy: 0.9742
# Epoch: 16, Loss: 0.0019, Test Accuracy: 0.9749
# Epoch: 17, Loss: 0.0017, Test Accuracy: 0.9751
# Epoch: 18, Loss: 0.0014, Test Accuracy: 0.9753
# Epoch: 19, Loss: 0.0013, Test Accuracy: 0.9754
# Epoch: 20, Loss: 0.0013, Test Accuracy: 0.9762
# Execution Time: 1117.83 seconds
# Hidden Layers: (100, 60), Learning Rate: 0.1
# Epoch: 1, Loss: 0.0062, Test Accuracy: 0.9410
# Epoch: 2, Loss: 0.0020, Test Accuracy: 0.9639
# Epoch: 3, Loss: 0.0022, Test Accuracy: 0.9696
# Epoch: 4, Loss: 0.0003, Test Accuracy: 0.9663
# Epoch: 5, Loss: 0.0076, Test Accuracy: 0.9680
# Epoch: 6, Loss: 0.0001, Test Accuracy: 0.9712
# Epoch: 7, Loss: 0.0013, Test Accuracy: 0.9694
# Epoch: 8, Loss: 0.0000, Test Accuracy: 0.9725
# Epoch: 9, Loss: 0.0004, Test Accuracy: 0.9692
# Epoch: 10, Loss: 0.0001, Test Accuracy: 0.9687
# Epoch: 11, Loss: 0.0000, Test Accuracy: 0.9738
# Epoch: 12, Loss: 0.0000, Test Accuracy: 0.9722
# Epoch: 13, Loss: 0.0000, Test Accuracy: 0.9706
# Epoch: 14, Loss: 0.0000, Test Accuracy: 0.9751
# Epoch: 15, Loss: 0.0000, Test Accuracy: 0.9712
# Epoch: 16, Loss: 0.0018, Test Accuracy: 0.9697
# Epoch: 17, Loss: 0.0000, Test Accuracy: 0.9730
# Epoch: 18, Loss: 0.0001, Test Accuracy: 0.9720
# Epoch: 19, Loss: 0.0000, Test Accuracy: 0.9721
# Epoch: 20, Loss: 0.0000, Test Accuracy: 0.9749
# Execution Time: 1170.61 seconds
# Hidden Layers: (100, 60), Learning Rate: 1.0
# Epoch: 1, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 2, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 3, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 4, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 5, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 6, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 7, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 8, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 9, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 10, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 11, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 12, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 13, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 14, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 15, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 16, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 17, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 18, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 19, Loss: 2.3437, Test Accuracy: 0.0958
# Epoch: 20, Loss: 2.3437, Test Accuracy: 0.0958
# Execution Time: 1059.15 seconds
